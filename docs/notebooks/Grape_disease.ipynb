# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import matplotlib.pyplot as plt

print('TF version:', tf.__version__)
print('GPU available:', tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.20.0
# GPU available: []

# %%
# Paths & Hyperparameters
TRAINING_PATH   = 'D:/FINAL YEAR_PROJECT/Disease_Classification/Plants_dataSet/Grape/Train'
VALIDATION_PATH = 'D:/FINAL YEAR_PROJECT/Disease_Classification/Plants_dataSet/Grape/Validation'

BATCH_SIZE   = 32
IMG_SIZE     = (224, 224)
EPOCHS_HEAD  = 15   # phase 1: train new head only
EPOCHS_FINE  = 20   # phase 2: fine-tune top layers
UNFREEZE_N   = 50   # how many base layers to unfreeze from the end
LR_HEAD      = 1e-3
LR_FINE      = 1e-5

# %%
## 2. Data Augmentation (KEY accuracy booster)
# Applied on-the-fly during training only
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal_and_vertical'),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.15),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.1),
], name='augmentation')

# %%
## 3. Load & Build Pipeline
training_set = tf.keras.utils.image_dataset_from_directory(
    TRAINING_PATH, label_mode='categorical',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=True, seed=42
)
validation_set = tf.keras.utils.image_dataset_from_directory(
    VALIDATION_PATH, label_mode='categorical',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False
)

class_names = training_set.class_names
NUM_CLASSES = len(class_names)
print(f'Classes ({NUM_CLASSES}):', class_names)

# Save for web app
#with open('class_names.json', 'w') as f:
#    json.dump(class_names, f)
#print('class_names.json saved')

AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    training_set
    .map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
    .map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE)
    .cache().prefetch(AUTOTUNE)
)

val_ds = (
    validation_set
    .map(lambda x, y: (preprocess_input(x), y), num_parallel_calls=AUTOTUNE)
    .cache().prefetch(AUTOTUNE)
)
# Out:
# Found 3251 files belonging to 4 classes.
# Found 811 files belonging to 4 classes.
# Classes (4): ['Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy']

# %%
## 4. Build Model (improved head with BatchNorm)
base_model = MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
base_model.trainable = False

inputs = tf.keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         327,936 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,625,476 (10.02 MB)
#  Trainable params: 364,420 (1.39 MB)
#  Non-trainable params: 2,261,056 (8.63 MB)

# %%
## 5. Phase 1 — Train head only
model.compile(
    optimizer=Adam(LR_HEAD),
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc')]
)

callbacks_head = [
    EarlyStopping(patience=5, restore_best_weights=True, monitor='val_accuracy', verbose=1),
    ModelCheckpoint('best_model_head.keras', save_best_only=True, monitor='val_accuracy'),
    ReduceLROnPlateau(factor=0.5, patience=3, min_lr=1e-7, verbose=1)
]

history = model.fit(train_ds, validation_data=val_ds,
                    epochs=EPOCHS_HEAD, callbacks=callbacks_head)
# Out:
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.8588 - loss: 0.3965 - top3_acc: 0.9825 - val_accuracy: 0.9716 - val_loss: 0.1322 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9514 - loss: 0.1218 - top3_acc: 0.9997 - val_accuracy: 0.9692 - val_loss: 0.0873 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9772 - loss: 0.0680 - top3_acc: 1.0000 - val_accuracy: 0.9704 - val_loss: 0.0964 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9849 - loss: 0.0436 - top3_acc: 0.9997 - val_accuracy: 0.9556 - val_loss: 0.1180 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - accuracy: 0.9910 - loss: 0.0281 - top3_acc: 1.0000
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9920 - loss: 0.0266 - top3_acc: 1.0000 - val_accuracy: 0.9494 - val_loss: 0.1398 - val_top3_acc: 1.0000 - learning_rate: 0.0010
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.9938 - loss: 0.0200 - top3_acc: 1.0000 - val_accuracy: 0.9741 - val_loss: 0.0906 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 139s 993ms/step - accuracy: 0.9975 - loss: 0.0093 - top3_acc: 1.0000 - val_accuracy: 0.9753 - val_loss: 0.1024 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9986 - loss: 0.0072 - top3_acc: 1.0000
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 101s 997ms/step - accuracy: 0.9972 - loss: 0.0084 - top3_acc: 1.0000 - val_accuracy: 0.9667 - val_loss: 0.1207 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-04
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9975 - loss: 0.0090 - top3_acc: 1.0000 - val_accuracy: 0.9716 - val_loss: 0.1035 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 101s 990ms/step - accuracy: 0.9985 - loss: 0.0053 - top3_acc: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1215 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9976 - loss: 0.0068 - top3_acc: 1.0000
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.9982 - loss: 0.0063 - top3_acc: 1.0000 - val_accuracy: 0.9729 - val_loss: 0.1152 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-04
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 1.0000 - loss: 0.0022 - top3_acc: 1.0000 - val_accuracy: 0.9729 - val_loss: 0.1157 - val_top3_acc: 1.0000 - learning_rate: 1.2500e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
## 6. Phase 2 — Fine-tune top base layers
base_model.trainable = True
for layer in base_model.layers[:-UNFREEZE_N]:
    layer.trainable = False

print(f'Fine-tuning {sum(1 for l in base_model.layers if l.trainable)} base layers')

model.compile(
    optimizer=Adam(LR_FINE),  # must be very low!
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc')]
)

callbacks_fine = [
    EarlyStopping(patience=7, restore_best_weights=True, monitor='val_accuracy', verbose=1),
    ModelCheckpoint('best_model_final.keras', save_best_only=True, monitor='val_accuracy'),
    ReduceLROnPlateau(factor=0.3, patience=4, min_lr=1e-8, verbose=1)
]

history_fine = model.fit(train_ds, validation_data=val_ds,
                         epochs=EPOCHS_FINE, callbacks=callbacks_fine)
# Out:
# Fine-tuning 50 base layers
# Epoch 1/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.9114 - loss: 0.3057 - top3_acc: 0.9972 - val_accuracy: 0.9766 - val_loss: 0.1075 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9609 - loss: 0.1124 - top3_acc: 1.0000 - val_accuracy: 0.9729 - val_loss: 0.1110 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 3/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9843 - loss: 0.0442 - top3_acc: 1.0000 - val_accuracy: 0.9729 - val_loss: 0.1113 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 4/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9908 - loss: 0.0314 - top3_acc: 1.0000 - val_accuracy: 0.9766 - val_loss: 0.0956 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 5/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9926 - loss: 0.0243 - top3_acc: 1.0000 - val_accuracy: 0.9803 - val_loss: 0.0895 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 6/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9963 - loss: 0.0156 - top3_acc: 1.0000 - val_accuracy: 0.9840 - val_loss: 0.0842 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 7/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9975 - loss: 0.0115 - top3_acc: 1.0000 - val_accuracy: 0.9778 - val_loss: 0.0886 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 8/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9994 - loss: 0.0091 - top3_acc: 1.0000 - val_accuracy: 0.9790 - val_loss: 0.0874 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 9/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9988 - loss: 0.0084 - top3_acc: 1.0000 - val_accuracy: 0.9803 - val_loss: 0.0869 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 10/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9983 - loss: 0.0090 - top3_acc: 1.0000
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9985 - loss: 0.0083 - top3_acc: 1.0000 - val_accuracy: 0.9803 - val_loss: 0.0865 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05
# Epoch 11/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9978 - loss: 0.0084 - top3_acc: 1.0000 - val_accuracy: 0.9803 - val_loss: 0.0873 - val_top3_acc: 1.0000 - learning_rate: 3.0000e-06
# Epoch 12/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9988 - loss: 0.0053 - top3_acc: 1.0000 - val_accuracy: 0.9778 - val_loss: 0.0906 - val_top3_acc: 1.0000 - learning_rate: 3.0000e-06
# Epoch 13/20
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9991 - loss: 0.0057 - top3_acc: 1.0000 - val_accuracy: 0.9766 - val_loss: 0.0964 - val_top3_acc: 1.0000 - learning_rate: 3.0000e-06
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
def plot_combined(h1, h2, metric='accuracy'):
    v1, val1 = h1.history[metric], h1.history[f'val_{metric}']
    v2, val2 = h2.history[metric], h2.history[f'val_{metric}']
    e1 = range(1, len(v1)+1)
    e2 = range(len(v1)+1, len(v1)+len(v2)+1)
    plt.figure(figsize=(12,5))
    plt.plot(list(e1), v1, 'b-',  label='Head Train')
    plt.plot(list(e1), val1, 'b--', label='Head Val')
    plt.plot(list(e2), v2, 'r-',  label='Fine-tune Train')
    plt.plot(list(e2), val2, 'r--', label='Fine-tune Val')
    plt.axvline(x=len(v1), color='gray', linestyle=':', label='Fine-tune start')
    plt.title(f'{metric.capitalize()} over full training')
    plt.xlabel('Epoch'); plt.ylabel(metric); plt.legend(); plt.grid(True)
    plt.tight_layout(); plt.savefig(f'training_{metric}.png', dpi=150); plt.show()

plot_combined(history, history_fine, 'accuracy')
plot_combined(history, history_fine, 'loss')

# %% [markdown]
# best = tf.keras.models.load_model('best_model_final.keras')
# best.save('Grape_disease.keras')
# print('Saved: Grape_disease.keras')
#
# loss, acc, top3 = best.evaluate(val_ds)
# print(f'\nVal Accuracy  : {acc*100:.2f}%')
# print(f'Top-3 Accuracy: {top3*100:.2f}%')
